# %% [markdown]
# ***Question 1:*** Compare and contrast NLTK and spaCy in terms of features, ease of use,
# and performance.
#
# ***Answer-***
#
# NLTK and spaCy are popular Python libraries for Natural Language Processing. NLTK
# provides many tools for tasks like tokenization, stemming, tagging, and parsing, mainly
# used for education and research. spaCy is designed for production applications and
# offers faster processing with built-in features like named entity recognition and
# dependency parsing. NLTK is more flexible but slower. spaCy is easier to use and
# optimized for performance. Therefore, NLTK is best for learning NLP, while spaCy is
# better for real-world applications.

# %% [markdown]
# ***Question 2:*** What is TextBlob and how does it simplify common NLP tasks like
# sentiment analysis and translation?
#
#
# ***ANSWER-***
#
# TextBlob is a simple Python library used for performing common NLP tasks. It is built
# on top of NLTK and Pattern libraries. TextBlob helps in tasks such as sentiment
# analysis, translation, part-of-speech tagging, and noun phrase extraction. It provides
# polarity and subjectivity scores for sentiment analysis. The library is easy to use and
# requires very little code. Therefore, TextBlob is widely used for beginners and quick
# NLP experiments.

# %% [markdown]
# Question 3: Explain the role of Standford NLP in academic and industry NLP Projects.
#
# Answer:
#
# Stanford NLP is a collection of natural language processing tools developed by
# Stanford University. It is widely used in academic research and industry applications. It
# provides tools for tasks such as named entity recognition, dependency parsing,
# sentiment analysis, and coreference resolution. Researchers use it for analyzing
# linguistic structures and large text datasets. Companies use it for applications like
# chatbots, search engines, and text analysis systems. Its CoreNLP toolkit is known for
# high accuracy and reliability.
#
#
# ***Question 4:*** Describe the architecture and functioning of a Recurrent Natural Network
# (RNN).
#
# ***Answer:***
#
# A Recurrent Neural Network (RNN) is a type of neural network used for processing
# sequential data such as text and speech. It has an input layer, hidden layer, and output
# layer. The hidden layer stores information from previous inputs using a feedback loop.
# This allows the network to remember past information while processing new data.
# RNNs are commonly used in language modeling, machine translation, and speech
# recognition. However, they may suffer from the vanishing gradient problem when
# learning long sequences.

# %% [markdown]
# ***Question 5:*** What is the key difference between LSTM and GRU networks in NLP
# applications?
#
#
# ***Answer:***
#
#
# LSTM and GRU are advanced types of recurrent neural networks designed to solve the
# vanishing gradient problem. LSTM uses three gates: input, forget, and output gates to
# control information flow. GRU uses two gates: update and reset gates, making it
# simpler than LSTM. LSTM can capture long-term dependencies better but is more
# complex. GRU is faster to train and requires fewer parameters. Both are widely used in
# NLP tasks such as text classification and language modeling.

# %%
'''
Question 6: Write a Python program using TextBlob to perform sentiment analysis on
the following paragraph of text:
“I had a great experience using the new mobile banking app. The interface is intuitive,
and customer support was quick to resolve my issue. However, the app did crash once
during a transaction, which was frustrating"
Your program should print out the polarity and subjectivity scores.
(Include your Python code and output in the code box below.)
Answer:
'''


from textblob import TextBlob
text = """I had a great experience using the new mobile banking app. The interface is intuitive, and customer support was quick to resolve my issue.
However, the app did crash once during a transaction, which was
frustrating."""
blob = TextBlob(text)
print("Polarity:", blob.sentiment.polarity)
print("Subjectivity:", blob.sentiment.subjectivity)
# Out:
# Polarity: 0.21742424242424244
# Subjectivity: 0.6511363636363636

# %%
'''
Question 7: Given the sample paragraph below, perform string tokenization and
frequency distribution using Python and NLTK: Natural Language Processing (NLP) is a fascinating field that combines linguistics,
computer science, and artificial intelligence. It enables machines to understand,
interpret, and generate human language. Applications of NLP include chatbots,
sentiment analysis, and machine translation. As technology advances, the role of NLP
in modern solutions is becoming increasingly critical.”
(Include your Python code and output in the code box below.)
Answer:
'''
import nltk
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist
text = """Natural Language Processing (NLP) is a fascinating field that combines linguistics, computer science, and artificial intelligence. It enables machines to understand, interpret, and generate human language."""
tokens = word_tokenize(text)
fdist = FreqDist(tokens)
print("Tokens:")
print(tokens)
print("\nFrequency Distribution:")
print(fdist.most_common(10))

#OUTPUT:-
Tokens:
['Natural', 'Language', 'Processing', '(', 'NLP', ')', 'is', 'a', 'fascinating', 'field', 'that',
'combines', 'linguistics', ',', 'computer', 'science', ',', 'and', 'artificial', 'intelligence', '.', 'It',
'enables', 'machines', 'to', 'understand', ',', 'interpret', ',', 'and', 'generate', 'human',
'language', '.']
Frequency Distribution:
[(',', 4), ('and', 2), ('.', 2), ('Natural', 1), ('Language', 1), ('Processing', 1), ('(', 1), ('NLP', 1),
(')', 1), ('is', 1)]

# %%
'''Question 8: Implement a basic LSTM model in Keras for a text classification task using
the following dummy dataset. Your model should classify sentences as either positive
(1) or negative (0).
# Dataset
texts = [
“I love this project”, #Positive
“This is an amazing experience”, #Positive
“I hate waiting in line”, #Negative
“This is the worst service”, #Negative
“Absolutely fantastic!” #Positive
]
labels = [1, 1, 0, 0, 1]
Preprocess the text, tokenize it, pad sequences, and build an LSTM model to train on
this data. You may use Keras with TensorFlow backend.
(Include your Python code and output in the code box below.)
'''

import numpy as np
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense
texts = [
"I love this project",
"This is an amazing experience",
"I hate waiting in line",
"This is the worst service",
"Absolutely fantastic!"
]
labels = [1,1,0,0,1]
labels = np.array(labels)
tokenizer = Tokenizer()
tokenizer.fit_on_texts(texts)
sequences = tokenizer.texts_to_sequences(texts)
padded = pad_sequences(sequences, maxlen=5)
model = Sequential()
model.add(Embedding(input_dim=50, output_dim=8))
model.add(LSTM(16))
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='adam', loss='binary_crossentropy',
metrics=['accuracy'])
model.fit(padded, labels, epochs=10)
print("Model training completed")
# Out:
# Epoch 1/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - accuracy: 0.6000 - loss: 0.6931
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8000 - loss: 0.6919
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8000 - loss: 0.6908
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.6000 - loss: 0.6897
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.6000 - loss: 0.6886
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.6000 - loss: 0.6875
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.6000 - loss: 0.6864
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.6000 - loss: 0.6853
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.6000 - loss: 0.6841
# Epoch 10/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.6000 - loss: 0.6829
# Model training completed

# %%
'''
Question 9: Using spaCy, build a simple NLP pipeline that includes tokenization,
lemmatization, and entity recognition. Use the following paragraph as your dataset:
“Homi Jehangir Bhaba was an Indian nuclear physicist who played a key role in the
development of India’s atomic energy program. He was the founding director of the Tata
Institute of Fundamental Research (TIFR) and was instrumental in establishing the
Atomic Energy Commission of India.”
Write a Python program that processes this text using spaCy, then prints tokens, their
lemmas, and any named entities found.
(Include your Python code and output in the code box below.)

'''


import spacy
nlp = spacy.load("en_core_web_sm")
text = """Homi Jehangir Bhabha was an Indian nuclear physicist who
played a key role
in the development of India’s atomic energy program."""
doc = nlp(text)
print("Tokens and Lemmas:")
for token in doc:
 print(token.text, "->", token.lemma_)
print("\nNamed Entities:")
for ent in doc.ents:
 print(ent.text, "-", ent.label_)
# Out:
# Tokens and Lemmas:
# Homi -> Homi
# Jehangir -> Jehangir
# Bhabha -> Bhabha
# was -> be
# an -> an
# Indian -> indian
# nuclear -> nuclear
# physicist -> physicist
# who -> who
#
#  ->
#
# played -> play
# a -> a
# key -> key
# role -> role
#
#  ->
#
# in -> in
# the -> the
# development -> development
# of -> of
# India -> India
# ’s -> ’s
# atomic -> atomic
# energy -> energy
# program -> program
# . -> .
#
# Named Entities:
# Homi Jehangir Bhabha - PERSON
# Indian - NORP
# India - GPE

# %% [markdown]
# ***Question 10:*** You are working on a chatbot for a mental health platform. Explain how
# you would leverage LSTM or GRU networks along with libraries like spaCy or Stanford
# NLP to understand and respond to user input effectively. Detail your architecture, data
# preprocessing pipeline, and any ethical considerations.
# (Include your Python code and output in the code box below.)
#
#
# ***Answer:***
#
#
# A mental health chatbot can use spaCy or Stanford NLP for text
# preprocessing tasks such as tokenization, lemmatization, and entity
# recognition. The processed text is then passed to an LSTM or GRU neural
# network, which understands the sequence of words and predicts the user's
# intent. The architecture includes an input layer, embedding layer,
# LSTM/GRU layer, and a dense output layer for response prediction. The
# chatbot can then generate helpful responses using predefined templates
# or a response generation model. Ethical considerations include
# maintaining user privacy, avoiding harmful advice, and ensuring the
# chatbot encourages users to seek professional help when necessary.
